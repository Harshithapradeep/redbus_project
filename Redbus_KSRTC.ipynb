# %%
#To import the functions from Redbus_common jupyter notebook
# %run "C:\Users\hbhat\OneDrive\Desktop\VScode\redbus_project\Redbus_Common.ipynb"

# %%
#CSV file name for RTC 
rtc_service='ksrtc-kerala'
csv_file = f'./output_csv/{rtc_service}.csv'

# %%
#Function to call page_navigation and route_name and route_links
rtc_list = page_navigation(f"https://www.redbus.in/online-booking/{rtc_service}/?utm_source=rtchometile")
print(len(rtc_list))
# Out:
# Bangalore to Kozhikode https://www.redbus.in/bus-tickets/bangalore-to-kozhikode
# Kozhikode to Ernakulam https://www.redbus.in/bus-tickets/kozhikode-to-ernakulam
# Kozhikode to Bangalore https://www.redbus.in/bus-tickets/kozhikode-to-bangalore
# Ernakulam to Kozhikode https://www.redbus.in/bus-tickets/ernakulam-to-kozhikode
# Kozhikode to Mysore https://www.redbus.in/bus-tickets/kozhikode-to-mysore
# Kozhikode to Thiruvananthapuram https://www.redbus.in/bus-tickets/kozhikode-to-thiruvananthapuram
# Bangalore to Kalpetta (kerala) https://www.redbus.in/bus-tickets/bangalore-to-kalpetta
# Mysore to Kozhikode https://www.redbus.in/bus-tickets/mysore-to-kozhikode
# Kalpetta (kerala) to Bangalore https://www.redbus.in/bus-tickets/kalpetta-to-bangalore
# Kozhikode to Thrissur https://www.redbus.in/bus-tickets/kozhikode-to-thrissur
# Thiruvananthapuram to Kozhikode https://www.redbus.in/bus-tickets/thiruvananthapuram-to-kozhikode
# Bangalore to Kannur https://www.redbus.in/bus-tickets/bangalore-to-kannur
# Kozhikode to Kottayam https://www.redbus.in/bus-tickets/kozhikode-to-kottayam
# Kannur to Bangalore https://www.redbus.in/bus-tickets/kannur-to-bangalore
# Kottayam to Kozhikode https://www.redbus.in/bus-tickets/kottayam-to-kozhikode
# Thrissur to Kozhikode https://www.redbus.in/bus-tickets/thrissur-to-kozhikode
# Kozhikode to Kalpetta (kerala) https://www.redbus.in/bus-tickets/kozhikode-to-kalpetta
# Coimbatore to Ooty https://www.redbus.in/bus-tickets/coimbatore-to-ooty
# Kalpetta (kerala) to Kozhikode https://www.redbus.in/bus-tickets/kalpetta-to-kozhikode
# Reached the last page or could not find the next page button.3
# 19

# %%
#Scrape bus route information for all route_names and route_links and create pandas dataframe
df = pd.DataFrame(columns=['bus_route_name','bus_route_link','bus_name','bus_type','departing_time','duration','reaching_time','start_rating','price','seat_availability'])
for rno, route in enumerate(rtc_list):
    route_name = route['route_name']
    route_link = route['route_link']
    print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')} : INFO : '{rno}' '{route_name}','{route_link}'")
    df1=bus_route_details(route_name,route_link)
    df = pd.concat([df, df1], axis=0)
df
# Out:
# 2024-08-16 20:42:35 : INFO : '0' 'Bangalore to Kozhikode','https://www.redbus.in/bus-tickets/bangalore-to-kozhikode'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:43:07 : INFO : '1' 'Kozhikode to Ernakulam','https://www.redbus.in/bus-tickets/kozhikode-to-ernakulam'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:43:42 : INFO : '2' 'Kozhikode to Bangalore','https://www.redbus.in/bus-tickets/kozhikode-to-bangalore'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:44:13 : INFO : '3' 'Ernakulam to Kozhikode','https://www.redbus.in/bus-tickets/ernakulam-to-kozhikode'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:44:47 : INFO : '4' 'Kozhikode to Mysore','https://www.redbus.in/bus-tickets/kozhikode-to-mysore'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:45:18 : INFO : '5' 'Kozhikode to Thiruvananthapuram','https://www.redbus.in/bus-tickets/kozhikode-to-thiruvananthapuram'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:45:54 : INFO : '6' 'Bangalore to Kalpetta (kerala)','https://www.redbus.in/bus-tickets/bangalore-to-kalpetta'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:46:25 : INFO : '7' 'Mysore to Kozhikode','https://www.redbus.in/bus-tickets/mysore-to-kozhikode'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:46:53 : INFO : '8' 'Kalpetta (kerala) to Bangalore','https://www.redbus.in/bus-tickets/kalpetta-to-bangalore'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:47:25 : INFO : '9' 'Kozhikode to Thrissur','https://www.redbus.in/bus-tickets/kozhikode-to-thrissur'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:48:12 : INFO : '10' 'Thiruvananthapuram to Kozhikode','https://www.redbus.in/bus-tickets/thiruvananthapuram-to-kozhikode'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:48:44 : INFO : '11' 'Bangalore to Kannur','https://www.redbus.in/bus-tickets/bangalore-to-kannur'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:49:15 : INFO : '12' 'Kozhikode to Kottayam','https://www.redbus.in/bus-tickets/kozhikode-to-kottayam'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:49:46 : INFO : '13' 'Kannur to Bangalore','https://www.redbus.in/bus-tickets/kannur-to-bangalore'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:50:22 : INFO : '14' 'Kottayam to Kozhikode','https://www.redbus.in/bus-tickets/kottayam-to-kozhikode'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:50:57 : INFO : '15' 'Thrissur to Kozhikode','https://www.redbus.in/bus-tickets/thrissur-to-kozhikode'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:51:36 : INFO : '16' 'Kozhikode to Kalpetta (kerala)','https://www.redbus.in/bus-tickets/kozhikode-to-kalpetta'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:52:11 : INFO : '17' 'Coimbatore to Ooty','https://www.redbus.in/bus-tickets/coimbatore-to-ooty'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 20:52:36 : INFO : '18' 'Kalpetta (kerala) to Kozhikode','https://www.redbus.in/bus-tickets/kalpetta-to-kozhikode'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
#                     bus_route_name  \
# 0           Bangalore to Kozhikode
# 1           Bangalore to Kozhikode
# 2           Bangalore to Kozhikode
# 3           Bangalore to Kozhikode
# 4           Bangalore to Kozhikode
# ..                             ...
# 61  Kalpetta (kerala) to Kozhikode
# 62  Kalpetta (kerala) to Kozhikode
# 63  Kalpetta (kerala) to Kozhikode
# 64  Kalpetta (kerala) to Kozhikode
# 65  Kalpetta (kerala) to Kozhikode
#
#                                        bus_route_link               bus_name  \
# 0   https://www.redbus.in/bus-tickets/bangalore-to...   KSRTC (Kerala) - 581
# 1   https://www.redbus.in/bus-tickets/bangalore-to...    KSRTC (Kerala) - 52
# 2   https://www.redbus.in/bus-tickets/bangalore-to...  KSRTC (Kerala) - 1378
# 3   https://www.redbus.in/bus-tickets/bangalore-to...   KSRTC (Kerala) - 235
# 4   https://www.redbus.in/bus-tickets/bangalore-to...   KSRTC (Kerala) - 370
# ..                                                ...                    ...
# 61  https://www.redbus.in/bus-tickets/kalpetta-to-...             A1 Travels
# 62  https://www.redbus.in/bus-tickets/kalpetta-to-...         Cochin Express
# 63  https://www.redbus.in/bus-tickets/kalpetta-to-...         Cochin Express
# 64  https://www.redbus.in/bus-tickets/kalpetta-to-...          Sonia Travels
# 65  https://www.redbus.in/bus-tickets/kalpetta-to-...          Sonia Travels
#
#                                      bus_type departing_time duration  \
# 0   Super Express Non AC Seater Air Bus (2+2)          10:03  08h 45m
# 1                 SWIFT-GARUDA A/C SEATER BUS          12:01  07h 54m
# 2                               AC MULTI AXLE          13:46  07h 39m
# 3           Swift Deluxe Non AC Air Bus (2+2)          15:00  09h 01m
# 4                               AC MULTI AXLE          15:25  06h 55m
# ..                                        ...            ...      ...
# 61              Bharat Benz A/C Sleeper (2+1)          21:00  02h 30m
# 62                 A/C Seater Push Back (2+2)          22:30  01h 25m
# 63                 A/C Seater Push Back (2+2)          22:30  01h 25m
# 64                   A/C Seater/Sleeper (2+1)          19:30  03h 59m
# 65                   A/C Seater/Sleeper (2+1)          21:30  01h 59m
#
#    reaching_time start_rating price              seat_availability
# 0          18:48          4.1   469              3 Seats available
# 1          19:55          3.6   627             11 Seats available
# 2          21:25          2.5   729    5 Seats available\n1 Window
# 3          00:01          4.8   620   22 Seats available\n6 Window
# 4          22:20          2.5   729   11 Seats available\n5 Window
# ..           ...          ...   ...                            ...
# 61         23:30          3.3   800             35 Seats available
# 62         23:55          4.1   700  41 Seats available\n20 Window
# 63         23:55          4.1   700  41 Seats available\n20 Window
# 64         23:29          3.8   750             20 Seats available
# 65         23:29          3.8   750             20 Seats available
#
# [1044 rows x 10 columns]

# %%
#writes dataframe to a csv file 
df.to_csv(csv_file, index=False)
