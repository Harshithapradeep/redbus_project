# %%
#To import the functions from Redbus_common jupyter notebook
# %run "C:\Users\hbhat\OneDrive\Desktop\VScode\redbus_project\Redbus_Common.ipynb"

# %%
#CSV file name for RTC 
rtc_service='pepsu'
csv_file = f'./output_csv/{rtc_service}.csv'

# %%
#Function to call page_navigation and route_name and route_links
rtc_list = page_navigation(f"https://www.redbus.in/online-booking/{rtc_service}/?utm_source=rtchometile")
print(len(rtc_list))
# Out:
# Patiala to Delhi https://www.redbus.in/bus-tickets/patiala-to-delhi
# Delhi to Patiala https://www.redbus.in/bus-tickets/delhi-to-patiala
# Ludhiana to Delhi https://www.redbus.in/bus-tickets/ludhiana-to-delhi
# Delhi to Ludhiana https://www.redbus.in/bus-tickets/delhi-to-ludhiana
# Phagwara to Delhi https://www.redbus.in/bus-tickets/phagwara-to-delhi
# Jalandhar to Delhi https://www.redbus.in/bus-tickets/jalandhar-to-delhi
# Delhi to Jalandhar https://www.redbus.in/bus-tickets/delhi-to-jalandhar
# Patiala to Delhi Airport https://www.redbus.in/bus-tickets/patiala-to-delhi-airport
# Jalandhar to Delhi Airport https://www.redbus.in/bus-tickets/jalandhar-to-delhi-airport
# Ludhiana to Delhi Airport https://www.redbus.in/bus-tickets/ludhiana-to-delhi-airport
# Phagwara to Delhi Airport https://www.redbus.in/bus-tickets/phagwara-to-delhi-airport
# Delhi Airport to Ludhiana https://www.redbus.in/bus-tickets/delhi-airport-to-ludhiana
# Delhi to Phagwara https://www.redbus.in/bus-tickets/delhi-to-phagwara
# Delhi to Amritsar https://www.redbus.in/bus-tickets/delhi-to-amritsar
# Amritsar to Delhi https://www.redbus.in/bus-tickets/amritsar-to-delhi
# Delhi Airport to Patiala https://www.redbus.in/bus-tickets/delhi-airport-to-patiala
# Amritsar to Delhi Airport https://www.redbus.in/bus-tickets/amritsar-to-delhi-airport
# Kapurthala to Delhi https://www.redbus.in/bus-tickets/kapurthala-to-delhi
# Delhi Airport to Jalandhar https://www.redbus.in/bus-tickets/delhi-airport-to-jalandhar
# Chandigarh to Bathinda https://www.redbus.in/bus-tickets/chandigarh-to-bathinda
# Chandigarh to Faridkot https://www.redbus.in/bus-tickets/chandigarh-to-faridkot
# Chandigarh to Patiala https://www.redbus.in/bus-tickets/chandigarh-to-patiala
# Reached the last page or could not find the next page button.4
# 22

# %%
#Scrape bus route information for all route_names and route_links and create pandas dataframe
df = pd.DataFrame(columns=['bus_route_name','bus_route_link','bus_name','bus_type','departing_time','duration','reaching_time','start_rating','price','seat_availability'])
for rno, route in enumerate(rtc_list):
    route_name = route['route_name']
    route_link = route['route_link']
    print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')} : INFO : '{rno}' '{route_name}','{route_link}'")
    df1=bus_route_details(route_name,route_link)
    df = pd.concat([df, df1], axis=0)
df
# Out:
# 2024-08-16 21:05:25 : INFO : '0' 'Patiala to Delhi','https://www.redbus.in/bus-tickets/patiala-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16

# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
# 2024-08-16 21:16:45 : INFO : '21' 'Chandigarh to Patiala','https://www.redbus.in/bus-tickets/chandigarh-to-patiala'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# Creating Pandas Dataframe
#            bus_route_name                                     bus_route_link  \
# 0        Patiala to Delhi  https://www.redbus.in/bus-tickets/patiala-to-d...
# 1        Patiala to Delhi  https://www.redbus.in/bus-tickets/patiala-to-d...
# 2        Patiala to Delhi  https://www.redbus.in/bus-tickets/patiala-to-d...
# 3        Patiala to Delhi  https://www.redbus.in/bus-tickets/patiala-to-d...
# 4        Patiala to Delhi  https://www.redbus.in/bus-tickets/patiala-to-d...
# ..                    ...                                                ...
# 5   Chandigarh to Patiala  https://www.redbus.in/bus-tickets/chandigarh-t...
# 6   Chandigarh to Patiala  https://www.redbus.in/bus-tickets/chandigarh-t...
# 7   Chandigarh to Patiala  https://www.redbus.in/bus-tickets/chandigarh-t...
# 8   Chandigarh to Patiala  https://www.redbus.in/bus-tickets/chandigarh-t...
# 9   Chandigarh to Patiala  https://www.redbus.in/bus-tickets/chandigarh-t...
#
#                     bus_name                      bus_type departing_time  \
# 0     PEPSU (Punjab) - 66695         Volvo AC Seater (2+2)          04:20
# 1     PEPSU (Punjab) - 66646         Volvo AC Seater (2+2)          05:00
# 2     PEPSU (Punjab) - 66647         Volvo AC Seater (2+2)          06:15
# 3     PEPSU (Punjab) - 67139            AC Seater Hvac 2+2          09:05
# 4     PEPSU (Punjab) - 66648         Volvo AC Seater (2+2)          09:50
# ..                       ...                           ...            ...
# 5   Orbit Aviation Pvt. Ltd.              A/C Seater (2+2)          13:30
# 6   Orbit Aviation Pvt. Ltd.              A/C Seater (2+2)          13:55
# 7   Orbit Aviation Pvt. Ltd.              A/C Seater (2+2)          15:25
# 8   Orbit Aviation Pvt. Ltd.              A/C Seater (2+2)          16:55
# 9      NEW FATEH BUS SERVICE  Volvo A/C Semi Sleeper (2+2)          16:25
#
#    duration reaching_time start_rating price              seat_availability
# 0   05h 01m         09:21          3.9   692  34 Seats available\n15 Window
# 1   05h 01m         10:01          4.0   692  35 Seats available\n17 Window
# 2   05h 01m         11:16          4.0   692  28 Seats available\n12 Window
# 3   05h 01m         14:06          3.4   440  33 Seats available\n14 Window
# 4   05h 01m         14:51          4.0   692  26 Seats available\n10 Window
# ..      ...           ...          ...   ...                            ...
# 5   01h 50m         15:20          2.4   200  45 Seats available\n21 Window
# 6   01h 45m         15:40          2.5   200  43 Seats available\n20 Window
# 7   01h 20m         16:45          2.2   200  31 Seats available\n13 Window
# 8   01h 35m         18:30          2.7   200  39 Seats available\n18 Window
# 9   01h 35m         18:00          4.5   510             30 Seats available
#
# [815 rows x 10 columns]

# %%
#writes dataframe to a csv file 
df.to_csv(csv_file, index=False)
