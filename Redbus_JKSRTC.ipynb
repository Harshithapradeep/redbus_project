# %%
#To import the functions from Redbus_common jupyter notebook
# %run "C:\Users\hbhat\OneDrive\Desktop\VScode\redbus_project\Redbus_Common.ipynb"

# %%
#CSV file name for RTC 
rtc_service='jksrtc'
csv_file = f'./output_csv/{rtc_service}.csv'

# %%
#Function to call page_navigation and route_name and route_links
rtc_list = page_navigation(f"https://www.redbus.in/online-booking/{rtc_service}/?utm_source=rtchometile")
print(len(rtc_list))

# %%
#Scrape bus route information for all route_names and route_links and create pandas dataframe
df = pd.DataFrame(columns=['bus_route_name','bus_route_link','bus_name','bus_type','departing_time','duration','reaching_time','start_rating','price','seat_availability'])
for rno, route in enumerate(rtc_list):
    route_name = route['route_name']
    route_link = route['route_link']
    print(f"{datetime.now().strftime('%Y-%m-%d %H:%M:%S')} : INFO : '{rno}' '{route_name}','{route_link}'")
    df1=bus_route_details(route_name,route_link)
    df = pd.concat([df, df1], axis=0)
df
# Out:
# 2024-08-11 18:15:35 : INFO : '0' 'Delhi to Shimla','https://www.redbus.in/bus-tickets/delhi-to-shimla'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 23 23 23 23 23 23 23 23
# Creating Pandas Dataframe
# 2024-08-11 18:16:04 : INFO : '1' 'Shimla to Delhi','https://www.redbus.in/bus-tickets/shimla-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 14 14 14 14 14 14 14 14
# Creating Pandas Dataframe
# 2024-08-11 18:16:32 : INFO : '2' 'Manali to Chandigarh','https://www.redbus.in/bus-tickets/manali-to-chandigarh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 43 43 43 43 43 43 43 43
# Creating Pandas Dataframe
# 2024-08-11 18:17:02 : INFO : '3' 'Chandigarh to Manali','https://www.redbus.in/bus-tickets/chandigarh-to-manali'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 23 23 23 23 23 23 23 23
# Creating Pandas Dataframe
# 2024-08-11 18:17:30 : INFO : '4' 'Delhi to Manali','https://www.redbus.in/bus-tickets/delhi-to-manali'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 67 67 67 67 67 67 67 67
# Creating Pandas Dataframe
# 2024-08-11 18:18:08 : INFO : '5' 'Hamirpur (Himachal Pradesh) to Chandigarh','https://www.redbus.in/bus-tickets/hamirpur-himachal-pradesh-to-chandigarh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 4 4 4 4 4 4 4 4
# Creating Pandas Dataframe
# 2024-08-11 18:18:34 : INFO : '6' 'Delhi to Hamirpur (Himachal Pradesh)','https://www.redbus.in/bus-tickets/delhi-to-hamirpur-himachal-pradesh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 8 8 8 8 8 8 8 8
# Creating Pandas Dataframe
# 2024-08-11 18:19:01 : INFO : '7' 'Delhi to Chandigarh','https://www.redbus.in/bus-tickets/delhi-to-chandigarh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 172 172 172 172 172 172 172 172
# Creating Pandas Dataframe
# 2024-08-11 18:20:29 : INFO : '8' 'Manali to Delhi','https://www.redbus.in/bus-tickets/manali-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 31 31 31 31 31 31 31 31
# Creating Pandas Dataframe
# 2024-08-11 18:21:02 : INFO : '9' 'Hamirpur (Himachal Pradesh) to Delhi','https://www.redbus.in/bus-tickets/hamirpur-himachal-pradesh-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 6 6 6 6 6 6 6 6
# Creating Pandas Dataframe
# 2024-08-11 18:21:30 : INFO : '10' 'Chandigarh to Hamirpur (Himachal Pradesh)','https://www.redbus.in/bus-tickets/chandigarh-to-hamirpur-himachal-pradesh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 0 0 0 0 0 0 0 0
# Creating Pandas Dataframe
# 2024-08-11 18:21:53 : INFO : '11' 'Shimla to Manali','https://www.redbus.in/bus-tickets/shimla-to-manali'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 2 2 2 2 2 2 2 2
# Creating Pandas Dataframe
# 2024-08-11 18:22:18 : INFO : '12' 'Delhi to Dharamshala (Himachal Pradesh)','https://www.redbus.in/bus-tickets/delhi-to-dharamshala'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 35 35 35 35 35 35 35 35
# Creating Pandas Dataframe
# 2024-08-11 18:22:46 : INFO : '13' 'Shimla to Chandigarh','https://www.redbus.in/bus-tickets/shimla-to-chandigarh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 24 24 24 24 24 24 24 24
# Creating Pandas Dataframe
# 2024-08-11 18:23:14 : INFO : '14' 'Chandigarh to Dharamshala (Himachal Pradesh)','https://www.redbus.in/bus-tickets/chandigarh-to-dharamshala'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 7 7 7 7 7 7 7 7
# Creating Pandas Dataframe
# 2024-08-11 18:23:42 : INFO : '15' 'Delhi to Baddi (Himachal Pradesh)','https://www.redbus.in/bus-tickets/delhi-to-baddi-himachal-pradesh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 4 4 4 4 4 4 4 4
# Creating Pandas Dataframe
# 2024-08-11 18:24:09 : INFO : '16' 'Dharamshala (Himachal Pradesh) to Chandigarh','https://www.redbus.in/bus-tickets/dharamshala-to-chandigarh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 30 30 30 30 30 30 30 30
# Creating Pandas Dataframe
# 2024-08-11 18:24:37 : INFO : '17' 'Chamba (Himachal Pradesh) to Chandigarh','https://www.redbus.in/bus-tickets/chamba-himachal-pradesh-to-chandigarh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 1 1 1 1 1 1 1 1
# Creating Pandas Dataframe
# 2024-08-11 18:25:02 : INFO : '18' 'Delhi to Dalhousie','https://www.redbus.in/bus-tickets/delhi-to-dalhousie'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 5 5 5 5 5 5 5 5
# Creating Pandas Dataframe
# 2024-08-11 18:25:28 : INFO : '19' 'Delhi to Chamba (Himachal Pradesh)','https://www.redbus.in/bus-tickets/delhi-to-chamba-himachal-pradesh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 2 2 2 2 2 2 2 2
# Creating Pandas Dataframe
# 2024-08-11 18:25:54 : INFO : '20' 'Dalhousie to Delhi','https://www.redbus.in/bus-tickets/dalhousie-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 1 1 1 1 1 1 1 1
# Creating Pandas Dataframe
# 2024-08-11 18:26:18 : INFO : '21' 'Solan to Delhi','https://www.redbus.in/bus-tickets/solan-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 11 11 11 11 11 11 11 11
# Creating Pandas Dataframe
# 2024-08-11 18:26:47 : INFO : '22' 'Delhi to Palampur','https://www.redbus.in/bus-tickets/delhi-to-palampur'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 15 15 15 15 15 15 15 15
# Creating Pandas Dataframe
# 2024-08-11 18:27:14 : INFO : '23' 'Dharamshala (Himachal Pradesh) to Delhi','https://www.redbus.in/bus-tickets/dharamshala-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 28 28 28 28 28 28 28 28
# Creating Pandas Dataframe
# 2024-08-11 18:27:43 : INFO : '24' 'Delhi to Solan','https://www.redbus.in/bus-tickets/delhi-to-solan'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 19 19 19 19 19 19 19 19
# Creating Pandas Dataframe
# 2024-08-11 18:28:11 : INFO : '25' 'Chandigarh to Reckong Peo (Himachal Pradesh)','https://www.redbus.in/bus-tickets/chandigarh-to-reckong-peo-himachal-pradesh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 0 0 0 0 0 0 0 0
# Creating Pandas Dataframe
# 2024-08-11 18:28:35 : INFO : '26' 'Manali to Shimla','https://www.redbus.in/bus-tickets/manali-to-shimla'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 2 2 2 2 2 2 2 2
# Creating Pandas Dataframe
# 2024-08-11 18:29:00 : INFO : '27' 'Palampur to Delhi','https://www.redbus.in/bus-tickets/palampur-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 12 12 12 12 12 12 12 12
# Creating Pandas Dataframe
# 2024-08-11 18:29:27 : INFO : '28' 'Chandigarh to Kullu','https://www.redbus.in/bus-tickets/chandigarh-to-kullu'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 22 22 22 22 22 22 22 22
# Creating Pandas Dataframe
# 2024-08-11 18:29:56 : INFO : '29' 'Kangra to Chandigarh','https://www.redbus.in/bus-tickets/kangra-to-chandigarh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 28 28 28 28 28 28 28 28
# Creating Pandas Dataframe
# 2024-08-11 18:30:25 : INFO : '30' 'Kullu to Chandigarh','https://www.redbus.in/bus-tickets/kullu-to-chandigarh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 49 49 49 49 49 49 49 49
# Creating Pandas Dataframe
# 2024-08-11 18:30:56 : INFO : '31' 'Delhi to Kangra','https://www.redbus.in/bus-tickets/delhi-to-kangra'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 32 32 32 32 32 32 32 32
# Creating Pandas Dataframe
# 2024-08-11 18:31:26 : INFO : '32' 'Chamba (Himachal Pradesh) to Delhi','https://www.redbus.in/bus-tickets/chamba-himachal-pradesh-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 0 0 0 0 0 0 0 0
# Creating Pandas Dataframe
# 2024-08-11 18:31:48 : INFO : '33' 'Palampur to Chandigarh','https://www.redbus.in/bus-tickets/palampur-to-chandigarh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 13 13 13 13 13 13 13 13
# Creating Pandas Dataframe
# 2024-08-11 18:32:16 : INFO : '34' 'Chandigarh to Shimla','https://www.redbus.in/bus-tickets/chandigarh-to-shimla'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 3 3 3 3 3 3 3 3
# Creating Pandas Dataframe
# 2024-08-11 18:32:41 : INFO : '35' 'Chandigarh to Kangra','https://www.redbus.in/bus-tickets/chandigarh-to-kangra'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 8 8 8 8 8 8 8 8
# Creating Pandas Dataframe
# 2024-08-11 18:33:08 : INFO : '36' 'Delhi to Nalagarh','https://www.redbus.in/bus-tickets/delhi-to-nalagarh'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 3 3 3 3 3 3 3 3
# Creating Pandas Dataframe
# 2024-08-11 18:33:33 : INFO : '37' 'Baddi (Himachal Pradesh) to Delhi','https://www.redbus.in/bus-tickets/baddi-himachal-pradesh-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 1 1 1 1 1 1 1 1
# Creating Pandas Dataframe
# 2024-08-11 18:33:58 : INFO : '38' 'Kangra to Delhi','https://www.redbus.in/bus-tickets/kangra-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 27 27 27 27 27 27 27 27
# Creating Pandas Dataframe
# 2024-08-11 18:34:27 : INFO : '39' 'Ghumarwin to Delhi','https://www.redbus.in/bus-tickets/ghumarwin-to-delhi'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 2 2 2 2 2 2 2 2
# Creating Pandas Dataframe
# 2024-08-11 18:34:52 : INFO : '40' 'Delhi to Sarkaghat','https://www.redbus.in/bus-tickets/delhi-to-sarkaghat'
# No More View Buses Button
# Finding Bus Names
# Finding Bus Types
# Finding Bus Departing Time
# Finding Bus Duration
# Finding Bus Reaching Time
# Finding Bus Ticket Price
# Finding Bus Seat Availability
# Finding Bus Rating
# 2 2 2 2 2 2 2 2
# Creating Pandas Dataframe
#         bus_route_name                                     bus_route_link  \
# 0      Delhi to Shimla  https://www.redbus.in/bus-tickets/delhi-to-shimla
# 1      Delhi to Shimla  https://www.redbus.in/bus-tickets/delhi-to-shimla
# 2      Delhi to Shimla  https://www.redbus.in/bus-tickets/delhi-to-shimla
# 3      Delhi to Shimla  https://www.redbus.in/bus-tickets/delhi-to-shimla
# 4      Delhi to Shimla  https://www.redbus.in/bus-tickets/delhi-to-shimla
# ..                 ...                                                ...
# 26     Kangra to Delhi  https://www.redbus.in/bus-tickets/kangra-to-delhi
# 0   Ghumarwin to Delhi  https://www.redbus.in/bus-tickets/ghumarwin-to...
# 1   Ghumarwin to Delhi  https://www.redbus.in/bus-tickets/ghumarwin-to...
# 0   Delhi to Sarkaghat  https://www.redbus.in/bus-tickets/delhi-to-sar...
# 1   Delhi to Sarkaghat  https://www.redbus.in/bus-tickets/delhi-to-sar...
#
#             bus_name                            bus_type departing_time  \
# 0          HRTC - 93  Himsuta AC Seater Volvo/Scania 2+2          19:35
# 1         HRTC - 301          Ordinary 3+2 Non AC Seater          19:43
# 2         HRTC - 556          Ordinary 3+2 Non AC Seater          20:10
# 3         HRTC - 591                 A/C Executive (2+3)          21:00
# 4           HRTC - 8  Himsuta AC Seater Volvo/Scania 2+2          21:02
# ..               ...                                 ...            ...
# 26  Bharmani Travels        Volvo A/C Semi Sleeper (2+2)          21:05
# 0          HRTC - 78  Himsuta AC Seater Volvo/Scania 2+2          21:15
# 1          HRTC - 15  Himsuta AC Seater Volvo/Scania 2+2          21:25
# 0         HRTC - 557          Ordinary 3+2 Non AC Seater          20:15
# 1         HRTC - 597  Himsuta AC Seater Volvo/Scania 2+2          20:35
#
#    duration reaching_time start_rating price              seat_availability
# 0   09h 10m         04:45          3.8   892              2 Seats available
# 1   09h 47m         05:30          4.2   507               1 Seat available
# 2   09h 35m         05:45          4.5   507             10 Seats available
# 3   11h 15m         08:15          4.0   622  38 Seats available\n11 Window
# 4   09h 28m         06:30          4.4   892             12 Seats available
# ..      ...           ...          ...   ...                            ...
# 26  09h 55m         07:00          3.2   600   19 Seats available\n7 Window
# 0   07h 45m         05:00          4.5   892  30 Seats available\n12 Window
# 1   07h 05m         04:30          3.7   856              5 Seats available
# 0   10h 55m         07:10          2.9   575  36 Seats available\n11 Window
# 1   10h 05m         06:40          4.2  1078              8 Seats available
#
# [779 rows x 10 columns]

# %%
#writes dataframe to a csv file 
df.to_csv(csv_file, index=False)
